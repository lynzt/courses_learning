# %%
import codecs
import glob
import multiprocessing
import os
import re

import nltk
from nltk.corpus import stopwords
import gensim.models.word2vec as w2v
import sklearn.manifold
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# ability to split sentences (sentence boundary detection)...
nltk.download("punkt")
# common words to ignore
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# get book filenames
book_filenames = sorted(glob.glob('work/intro_deep_learning/35_hp/*.txt'))

print("Found books:")
book_filenames
# Out:
# Found books:
# ["work/intro_deep_learning/35_hp/Harry Potter 1 - Sorcerer's Stone.txt",
#  'work/intro_deep_learning/35_hp/Harry Potter 2 - Chamber of Secrets.txt',
#  'work/intro_deep_learning/35_hp/Harry Potter 3 - The Prisoner Of Azkaban.txt',
#  'work/intro_deep_learning/35_hp/Harry Potter 4 - The Goblet Of Fire.txt',
#  'work/intro_deep_learning/35_hp/Harry Potter 5 - Order of the Phoenix.txt',
#  'work/intro_deep_learning/35_hp/Harry Potter 6 - The Half Blood Prince.txt',
#  'work/intro_deep_learning/35_hp/Harry Potter 7 - Deathly Hollows.txt']

# %%
# corpus => collection of written texts (entire work of author or subject)
corpus_raw = u""
for book_filename in book_filenames:
    print("Reading '{0}'...".format(book_filename))
    with codecs.open(book_filename, "r", "utf-8") as book_file:
        corpus_raw += book_file.read()
    print("Corpus is now {0} characters long".format(len(corpus_raw)))
    print()
# Out:
# Reading 'work/intro_deep_learning/35_hp/Harry Potter 1 - Sorcerer's Stone.txt'...
# Corpus is now 448810 characters long
#
# Reading 'work/intro_deep_learning/35_hp/Harry Potter 2 - Chamber of Secrets.txt'...
# Corpus is now 947729 characters long
#
# Reading 'work/intro_deep_learning/35_hp/Harry Potter 3 - The Prisoner Of Azkaban.txt'...
# Corpus is now 1569784 characters long
#
# Reading 'work/intro_deep_learning/35_hp/Harry Potter 4 - The Goblet Of Fire.txt'...
# Corpus is now 2690176 characters long
#
# Reading 'work/intro_deep_learning/35_hp/Harry Potter 5 - Order of the Phoenix.txt'...
# Corpus is now 4190900 characters long
#
# Reading 'work/intro_deep_learning/35_hp/Harry Potter 6 - The Half Blood Prince.txt'...
# Corpus is now 5181714 characters long
#
# Reading 'work/intro_deep_learning/35_hp/Harry Potter 7 - Deathly Hollows.txt'...
# Corpus is now 6320858 characters long

# %%
# pickle - python specific way to serializes the data structure (binary)
# http://www.diveintopython3.net/serializing.html
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle') 
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
#convert into a list of words and clean...
stops = set(stopwords.words("english"))

def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()

    valid_words = [word.lower() for word in words if word.lower() not in stops]
    
    return valid_words

# %%
# sentence where each word is tokenized
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
print(raw_sentences[5])
print(sentence_to_wordlist(raw_sentences[5]))
# Out:
# The Dursleys had a small son called Dudley and in their opinion there was no finer boy anywhere.
# ['dursleys', 'small', 'son', 'called', 'dudley', 'opinion', 'finer', 'boy', 'anywhere']

# %%
# how many words
token_count = sum([len(sentence) for sentence in sentences])
print("The book corpus contains {0:,} tokens".format(token_count))
# Out:
# The book corpus contains 573,062 tokens

# %%
# build model - 
#DISTANCE, SIMILARITY, RANKING

# Dimensionality of the resulting word vectors.
# more dimensions, more computationally expensive to train but also more accurate
num_features = 300
# Minimum word count threshold.
min_word_count = 3

# Number of threads to run in parallel.
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 7

# Downsample setting for frequent words.
#0 - 1e-5 is good for this
downsampling = 1e-3

# Seed for the RNG, to make the results reproducible.
seed = 1

# gensim word2vec... gensim => generate similar
# discover semantic structure of documents
hp2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
# collect word and frequencies in internal tree struct
hp2vec.build_vocab(sentences)
print (hp2vec)
# Out:
# Word2Vec(vocab=11679, size=300, alpha=0.025)

# %%
# https://rare-technologies.com/word2vec-tutorial/#training
hp2vec.train(sentences, total_examples=hp2vec.corpus_count, epochs=hp2vec.epochs) # add total_examples, epocs
# Out:
# (2580844, 2865310)

# %%
if not os.path.exists("trained"):
    os.makedirs("trained")https://twitter.com/search?q=eoly23&src=typd

hp2vec.save(os.path.join("trained", "hp2vec.w2v"))

# %%
hp2vec = w2v.Word2Vec.load(os.path.join("trained", "hp2vec.w2v"))

# %%
#my video - how to visualize a dataset easily
# tsne => t-distributed Stochastic Neibor Embedding
# used for visualize high-dimensional data
# n_components => dimension of embeded space
# http://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html
tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)

# %%
all_word_vectors_matrix = hp2vec.wv.vectors # different

# %%
# Fit matrix into an embedded space and return that transformed output.
all_word_vectors_matrix_2d = tsne.fit_transform(all_word_vectors_matrix)

# %%
# https://pandas.pydata.org/pandas-docs/stable/dsintro.html#dataframe
# 2-d labled data struct (like sql table)
points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, all_word_vectors_matrix_2d[hp2vec.wv.vocab[word].index])
            for word in hp2vec.wv.vocab
        ]
    ],
    columns=["word", "x", "y"]
)

# %%
# first N rows
points.head(10)
# Out:
#        word          x          y
# 0     harry -15.250961 -43.591892
# 1    potter -72.104637 -15.910794
# 2  sorcerer -69.659592  -0.058497
# 3     stone  26.145342 -65.598610
# 4   chapter -25.215256 -16.062502
# 5       one -29.019558   0.845092
# 6       boy -41.809345 -35.646973
# 7     lived -70.558853  -3.065739
# 8        mr -28.609758 -29.751478
# 9       mrs -28.526278 -29.716265

# %%
# seaborn: statistical data visualization (https://seaborn.pydata.org/index.html)
# https://seaborn.pydata.org/generated/seaborn.set_context.html?highlight=set_context
# set_context: (paper, notebook, talk, poster)
sns.set_context('poster')

# %%
points.plot.scatter("x", "y", s=10, figsize=(20, 12))

# %%
def plot_region(x_bounds, y_bounds):
    slice = points[
        (x_bounds[0] <= points.x) &
        (points.x <= x_bounds[1]) & 
        (y_bounds[0] <= points.y) &
        (points.y <= y_bounds[1])
    ]
    
    
    ax = slice.plot.scatter("x", "y", s=35, figsize=(10, 8))
    for i, point in slice.iterrows():
        ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=11)

# %%
# plot_region(x_bounds=(4.0, 4.2), y_bounds=(-0.5, -0.1))
plot_region(x_bounds=(0, 3), y_bounds=(10, 15))

# %%
hp2vec.wv.most_similar("muggle")
# Out:
# [('borns', 0.8854010701179504),
#  ('children', 0.8601119518280029),
#  ('born', 0.8584277629852295),
#  ('wizarding', 0.8501237630844116),
#  ('bagshot', 0.8490949273109436),
#  ('artifacts', 0.8403252959251404),
#  ('misuse', 0.8394314050674438),
#  ('rr', 0.8359534740447998),
#  ('international', 0.831000566482544),
#  ('law', 0.8297675848007202)]

# %%
hp2vec.wv.most_similar("bellatrix")
# Out:
# [('narcissa', 0.9203916788101196),
#  ('greyback', 0.8741638660430908),
#  ('lestrange', 0.8415451049804688),
#  ('pettigrew', 0.8250620365142822),
#  ('lucius', 0.8236799240112305),
#  ('softly', 0.8138927221298218),
#  ('wormtail', 0.8074547648429871),
#  ('draco', 0.8064932227134705),
#  ('travers', 0.7695293426513672),
#  ('sneering', 0.7637427449226379)]

# %%
def nearest_similarity_cosmul(start1, end1, end2):
    similarities = hp2vec.wv.most_similar_cosmul(
        positive=[end2, start1],
        negative=[end1]
    )
    start2 = similarities[0][0]
    print("{start1} is related to {end1}, as {start2} is related to {end2}".format(**locals()))
    return start2

# %%
nearest_similarity_cosmul("harry", "ron", "draco")
# nearest_similarity_cosmul("Jaime", "sword", "wine")
# nearest_similarity_cosmul("Arya", "Nymeria", "dragons")
# Out:
# harry is related to ron, as lucius is related to draco
# 'lucius'
